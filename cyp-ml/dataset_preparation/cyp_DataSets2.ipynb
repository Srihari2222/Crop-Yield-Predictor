# %% [markdown]
# # Adding more components into dataset

# %%
import pandas as pd

# %%
fert=pd.read_csv('RAW_datasets/Fertilizer.csv')

# %%
crop=pd.read_csv('Processed_datasets/Final_Dataset_after_temperature.csv')

# %%
fert.head()
# Out:
#    Unnamed: 0              Crop   N   P   K   pH
# 0           0              Rice  80  40  40  5.5
# 1           1    Jowar(Sorghum)  80  40  40  5.5
# 2           2       Barley(JAV)  70  40  45  5.5
# 3           3             Maize  80  40  20  5.5
# 4           4  Ragi( naachnnii)  50  40  20  5.5

# %%
fert['Crop'].unique()
# Out:
# array(['Rice', 'Jowar(Sorghum)', 'Barley(JAV)', 'Maize',
#        'Ragi( naachnnii)', 'Chickpeas(Channa)', 'French Beans(Farasbi)',
#        'Fava beans (Papdi - Val)', 'Lima beans(Pavta)',
#        'Cluster Beans(Gavar)', 'Soyabean', 'Black eyed beans( chawli)',
#        'Kidney beans', 'pigeon peas(Toor Dal)', 'Moth bean(Matki)',
#        'Mung beans', 'Green Peas', 'Horse Gram(kulthi)', 'Black Gram',
#        'Rapeseed (Mohri)', 'Coriander seeds', 'Mustard seeds',
#        'sesame seed', 'Cumin seeds', 'Lentils(Masoor Dal)', 'Brinjal',
#        'Beetroot', 'Bitter Gourd', 'Bottle Gourd', 'Capsicum', 'Cabbage',
#        'Carrot', 'Cauliflower', 'Cucumber', 'Coriander leaves',
#        'Curry leaves', 'Drumstick – moringa', 'Chili', 'Lady Finger',
#        'Mushroom', 'Onion', 'Potato', 'Pumpkin', 'Radish', 'Olive',
#        'Sweet Potato', 'Fenugreek Leaf(methi)', 'Spinach', 'Ridgegourd',
#        'Gooseberry(Amla)', 'Jambun(Syzygium cumini)',
# ...

# %%
fert.sort_values(by='Crop',inplace=True)

# %%
fert.reset_index(0,inplace=True)

# %%
fert.head()
# Out:
#    index  Unnamed: 0        Crop   N   P   K    pH
# 0   1156        1156  Almond Nut  70  20  10  5.96
# 1    671         671  Almond Nut  70  20  10  6.12
# 2    768         768  Almond Nut  70  20  10  6.14
# 3    186         186  Almond Nut  70  20  10  6.02
# 4   1738        1738  Almond Nut  70  20  10  5.84

# %%
fert.drop(columns='Unnamed: 0',inplace=True,axis=1)

# %%
fert.head(10)
# Out:
#    index        Crop   N   P   K    pH
# 0   1156  Almond Nut  70  20  10  5.96
# 1    671  Almond Nut  70  20  10  6.12
# 2    768  Almond Nut  70  20  10  6.14
# 3    186  Almond Nut  70  20  10  6.02
# 4   1738  Almond Nut  70  20  10  5.84
# 5    574  Almond Nut  70  20  10  6.10
# 6   1253  Almond Nut  70  20  10  5.94
# 7   1447  Almond Nut  70  20  10  5.90
# 8   1835  Almond Nut  70  20  10  5.82
# 9    283  Almond Nut  70  20  10  6.04

# %%
fert[fert['Crop']=='Rice']
# Out:
#       index  Crop   N   P   K    pH
# 1577    388  Rice  80  40  40  5.58
# 1578     97  Rice  80  40  40  5.52
# 1579    776  Rice  80  40  40  5.66
# 1580    873  Rice  80  40  40  5.68
# 1581    679  Rice  80  40  40  5.64
# 1582   1746  Rice  80  40  40  5.32
# 1583    970  Rice  80  40  40  5.48
# 1584    582  Rice  80  40  40  5.62
# 1585   1552  Rice  80  40  40  5.36
# 1586    485  Rice  80  40  40  5.60
# 1587   1067  Rice  80  40  40  5.46
# 1588   1261  Rice  80  40  40  5.42
# 1589   1649  Rice  80  40  40  5.34
# 1590    291  Rice  80  40  40  5.56
# 1591   1358  Rice  80  40  40  5.40
# 1592    194  Rice  80  40  40  5.54
# 1593   1455  Rice  80  40  40  5.38
# 1594   1164  Rice  80  40  40  5.44
# 1595      0  Rice  80  40  40  5.50

# %%
fert.drop(columns='index',inplace=True,axis=1)

# %%
fert['Crop'].unique()
# Out:
# array(['almondnut', 'aniseed', 'apple', 'apricot', 'arecanut',
#        'asafoetida', 'ashgourd', 'banana', 'barley(jav)', 'bayleaf',
#        'beetroot', 'bittergourd', 'blackgram', 'blackpepper',
#        'blackeyedbeans(chawli)', 'bottlegourd', 'brinjal', 'cabbage',
#        'capsicum', 'cardamom', 'carrot', 'cashewnuts', 'cauliflower',
#        'chickoo', 'chickpea', 'chili', 'cinnamon', 'cloves',
#        'clusterbeans(gavar)', 'coconut', 'coffee', 'corianderleaves',
#        'corianderseeds', 'cotton', 'cucumber', 'cuminseeds',
#        'curryleaves', 'custardapple', 'dates', 'drumstick–moringa',
#        'favabeans(papdi-val)', 'fenugreekleaf(methi)', 'figs',
#        'frenchbeans(farasbi)', 'garciniaindica(kokam)', 'garlic',
#        'ginger', 'gooseberry(amla)', 'grapes', 'greenpeas', 'guava',
#        'horsegram(kulthi)', 'jackfruit', 'jaiphal(nutmeg)',
#        'jambun(syzygiumcumini)', 'jowar(sorghum)', 'jute', 'kidneybeans',
# ...

# %%
def change_case(i):
    i = i.replace(" ", "")
    i = i.lower()
    return i

# %%
def remove_brackets(i):
    if '(' not in i:return i
    temp=''
    for j in i:
        if j=='(':return temp
        temp+=j

# %%
fert['Crop'] = fert['Crop'].apply(change_case)

fert['Crop'] = fert['Crop'].replace('mungbeans','mungbean')
fert['Crop'] = fert['Crop'].replace('lentils(masoordal)','lentil')
fert['Crop'] = fert['Crop'].replace('pigeonpeas(toordal)','pigeonpeas')
fert['Crop'] = fert['Crop'].replace('mothbean(matki)','mothbeans')
fert['Crop'] = fert['Crop'].replace('chickpeas(channa)','chickpea')

# %%
fert['Crop']=fert['Crop'].replace('barley(jav)','barley')

# %%
fert.sample(30)
# Out:
#                     Crop    N   P    K    pH
# 66               apricot   40  50   25  6.36
# 622       corianderseeds   90  20   20  6.46
# 676           cuminseeds   90  60   20  6.58
# 74               apricot   40  50   25  6.64
# 1234               mango   20  20   30  5.02
# 1612          ridgegourd   90  50   20  6.66
# 1526                ragi   50  40   20  5.36
# 1796  ziziphusmauritiana   20  10   10  5.84
# 701          curryleaves   20  20   20  6.68
# 811                 figs   20  60   20  5.06
# 80              arecanut  100  40  140  6.18
# 1747              tomato  100  40   90  5.98
# 14             almondnut   70  20   10  6.06
# 702          curryleaves   20  20   20  6.54
# 1221               mango   20  20   30  4.98
# 1258            mungbean   20  40   20  5.40
# 1430        pistachionut   90  20   20  5.98
# 655             cucumber   60  60   85  6.38
# 1096         kidneybeans   20  60   20  5.68
# 183              bayleaf  100  50   25  4.90
# ...

# %%
crop.head()
# Out:
#        State_Name Crop_Type          Crop  rainfall  temperature  \
# 0  andhra pradesh    kharif     Arhar/Tur    654.34    29.266667
# 1  andhra pradesh    kharif         Bajra    654.34    29.266667
# 2  andhra pradesh    kharif   Castor seed    654.34    29.266667
# 3  andhra pradesh    kharif        Cotton    654.34    29.266667
# 4  andhra pradesh    kharif  Dry chillies    654.34    29.266667
#
#    Area_in_hectares  Production_in_tons  Yield_ton_per_hec
# 0           21400.0              2600.0           0.121495
# 1            1400.0               500.0           0.357143
# 2            1000.0               100.0           0.100000
# 3            7300.0              9400.0           1.287671
# 4            3700.0              7100.0           1.918919

# %%
crop['Crop']=crop['Crop'].apply(remove_brackets)

# %%
fert['Crop']=fert['Crop'].apply(remove_brackets)

# %%
crop['Crop']=crop['Crop'].apply(change_case)

# %%
len(crop['Crop'].unique())
# Out:
# 114

# %%
len(fert['Crop'].unique())
# Out:
# 97

# %%
crop['Crop'] = crop['Crop'].replace('bhindi','ladyfinger')

# %%
crop['Crop']=crop['Crop'].replace('pomegranet','pomegranate')

# %%
crop['Crop']=crop['Crop'].replace('horse-gram','horsegram')

# %%
fert['Crop']=fert['Crop'].replace('corianderleaves','coriander')

# %%
fert['Crop']=fert['Crop'].replace('drumstick–moringa','drumstick')

# %%
fert['Crop']=fert['Crop'].replace('sesameseed','sesamum')

# %%
crop['Crop']=crop['Crop'].replace('cashewnut','cashewnuts')

# %%
fert['Crop']=fert['Crop'].replace('mungbean','moong')

# %%
crop['Crop']=crop['Crop'].replace('redish','radish')

# %%
crop['Crop']=crop['Crop'].replace('ribedguard','ridgegourd')

# %%
crop['Crop']=crop['Crop'].replace('rapeseed&mustard','rapeseed')

# %%
fert.head(20)
# Out:
#          Crop    N   P   K    pH
# 0   almondnut   70  20  10  5.96
# 1   almondnut   70  20  10  6.12
# 2   almondnut   70  20  10  6.14
# 3   almondnut   70  20  10  6.02
# 4   almondnut   70  20  10  5.84
# 5   almondnut   70  20  10  6.10
# 6   almondnut   70  20  10  5.94
# 7   almondnut   70  20  10  5.90
# 8   almondnut   70  20  10  5.82
# 9   almondnut   70  20  10  6.04
# 10  almondnut   70  20  10  6.08
# 11  almondnut   70  20  10  5.88
# 12  almondnut   70  20  10  6.00
# 13  almondnut   70  20  10  5.98
# 14  almondnut   70  20  10  6.06
# 15  almondnut   70  20  10  6.16
# 16  almondnut   70  20  10  6.18
# 17  almondnut   70  20  10  5.86
# 18  almondnut   70  20  10  5.92
# 19    aniseed  100  50  20  5.00

# %% [markdown]
# ##### analyzing the states in two datasets

# %%
print(sorted(list(crop['Crop'].unique())))
# Out:
# ['apple', 'arcanut', 'arecanut', 'arhar/tur', 'ashgourd', 'atcanut', 'bajra', 'banana', 'barley', 'beans&mutter', 'beetroot', 'ber', 'bittergourd', 'blackgram', 'blackpepper', 'bottlegourd', 'brinjal', 'cabbage', 'cardamom', 'carrot', 'cashewnutprocessed', 'cashewnutraw', 'cashewnuts', 'castorseed', 'cauliflower', 'citrusfruit', 'coffee', 'cond-spcsother', 'coriander', 'cotton', 'cowpea', 'cucumber', 'drumstick', 'drychillies', 'dryginger', 'garlic', 'ginger', 'gram', 'grapes', 'groundnut', 'guarseed', 'horsegram', 'jackfruit', 'jowar', 'jute', 'jute&mesta', 'kapas', 'khesari', 'korra', 'lab-lab', 'ladyfinger', 'linseed', 'litchi', 'maize', 'mango', 'masoor', 'mesta', 'moong', 'moth', 'nigerseed', 'oilseedstotal', 'onion', 'orange', 'othercereals&millets', 'othercitrusfruit', 'otherdryfruit', 'otherfibres', 'otherfreshfruits', 'otherkharifpulses', 'othermisc.pulses', 'otheroilseeds', 'otherrabipulses', 'othervegetables', 'paddy', 'papaya', 'peach', 'pear', 'peas', 'peas&beans', 'pine
# ...

# %%
print(sorted(fert['Crop'].unique()))
# Out:
# ['almondnut', 'aniseed', 'apple', 'apricot', 'arecanut', 'asafoetida', 'ashgourd', 'banana', 'barley', 'bayleaf', 'beetroot', 'bittergourd', 'blackeyedbeans', 'blackgram', 'blackpepper', 'bottlegourd', 'brinjal', 'cabbage', 'capsicum', 'cardamom', 'carrot', 'cashewnuts', 'cauliflower', 'chickoo', 'chickpea', 'chili', 'cinnamon', 'cloves', 'clusterbeans', 'coconut', 'coffee', 'coriander', 'corianderseeds', 'cotton', 'cucumber', 'cuminseeds', 'curryleaves', 'custardapple', 'dates', 'drumstick', 'favabeans', 'fenugreekleaf', 'figs', 'frenchbeans', 'garciniaindica', 'garlic', 'ginger', 'gooseberry', 'grapes', 'greenpeas', 'guava', 'horsegram', 'jackfruit', 'jaiphal', 'jambun', 'jowar', 'jute', 'kidneybeans', 'ladyfinger', 'lemon', 'lemongrass', 'lentil', 'limabeans', 'maize', 'mango', 'moong', 'mothbeans', 'mushroom', 'muskmelon', 'mustardseeds', 'olive', 'onion', 'orange', 'papaya', 'pigeonpeas', 'pineapple', 'pistachionut', 'pomegranate', 'potato', 'pumpkin', 'radish', 'ragi', 'raisins
# ...

# %%
print(len(set(crop['Crop'])&set(fert['Crop'])))
# Out:
# 53

# %%
print(sorted(crop['Crop'].unique()).index('clusterbeans'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 print(sorted(crop['Crop'].unique()).index('clusterbeans'))
#
# ValueError: 'clusterbeans' is not in list

# %%
a=sorted(fert['Crop'].unique())

# %%
b=sorted(crop['Crop'].unique())

# %%
new_row=['wheat',60,30,30,7.0]
fert.loc[len(fert)]=new_row

# %%
fert.tail()
# Out:
#        Crop   N   P   K    pH
# 1849  wheat  60  30  30  6.90
# 1850  wheat  60  30  30  6.10
# 1851  wheat  60  30  30  6.11
# 1852  wheat  60  30  30  6.12
# 1853  wheat  60  30  30  7.00

# %%
crop.head()
# Out:
#        State_Name Crop_Type         Crop  rainfall  temperature  \
# 0  andhra pradesh    kharif    arhar/tur    654.34    29.266667
# 1  andhra pradesh    kharif        bajra    654.34    29.266667
# 2  andhra pradesh    kharif   castorseed    654.34    29.266667
# 3  andhra pradesh    kharif       cotton    654.34    29.266667
# 4  andhra pradesh    kharif  drychillies    654.34    29.266667
#
#    Area_in_hectares  Production_in_tons  Yield_ton_per_hec
# 0           21400.0              2600.0           0.121495
# 1            1400.0               500.0           0.357143
# 2            1000.0               100.0           0.100000
# 3            7300.0              9400.0           1.287671
# 4            3700.0              7100.0           1.918919

# %%
fert.head()
# Out:
#         Crop   N   P   K    pH
# 0  almondnut  70  20  10  5.96
# 1  almondnut  70  20  10  6.12
# 2  almondnut  70  20  10  6.14
# 3  almondnut  70  20  10  6.02
# 4  almondnut  70  20  10  5.84

# %%
c=[]
for i in b:
    if i not in a:c.append(i)

# %%
print(c)
# Out:
# ['arcanut', 'arhar/tur', 'atcanut', 'bajra', 'beans&mutter', 'ber', 'cashewnutprocessed', 'cashewnutraw', 'castorseed', 'citrusfruit', 'cond-spcsother', 'cowpea', 'drychillies', 'dryginger', 'gram', 'groundnut', 'guarseed', 'jute&mesta', 'kapas', 'khesari', 'korra', 'lab-lab', 'linseed', 'litchi', 'masoor', 'mesta', 'moth', 'nigerseed', 'oilseedstotal', 'othercereals&millets', 'othercitrusfruit', 'otherdryfruit', 'otherfibres', 'otherfreshfruits', 'otherkharifpulses', 'othermisc.pulses', 'otheroilseeds', 'otherrabipulses', 'othervegetables', 'paddy', 'peach', 'pear', 'peas', 'peas&beans', 'plums', 'pomefruit', 'pulsestotal', 'rubber', 'safflower', 'samai', 'sannhamp', 'smallmillets', 'snakguard', 'sugarcane', 'tea', 'tobacco', 'totalfoodgrain', 'turnip', 'urad', 'varagu', 'yam']

# %% [markdown]
# ##### dropping the crops which are not present in fertilizer.csv

# %%
crop=crop[~crop['Crop'].isin(c)]

# %%
crop.shape
# Out:
# (99849, 8)

# %%
crop.reset_index(0,inplace=True)

# %%
crop.head()
# Out:
#        State_Name Crop_Type       Crop  rainfall  temperature  \
# 0  andhra pradesh    kharif     cotton    654.34    29.266667
# 1  andhra pradesh    kharif  horsegram    654.34    29.266667
# 2  andhra pradesh    kharif      jowar    654.34    29.266667
# 3  andhra pradesh    kharif      maize    654.34    29.266667
# 4  andhra pradesh    kharif      moong    654.34    29.266667
#
#    Area_in_hectares  Production_in_tons  Yield_ton_per_hec
# 0            7300.0              9400.0           1.287671
# 1            3300.0              1000.0           0.303030
# 2           10100.0             10200.0           1.009901
# 3            2800.0              4900.0           1.750000
# 4            1300.0               500.0           0.384615

# %%
del crop['index']

# %% [markdown]
# # Merging the fertilizer.csv data into main dataset

# %%
crop.insert(3,'N',[0 for i in range(len(crop))])

# %%
crop.insert(4,'P',[0 for i in range(len(crop))])

# %%
crop.insert(5,'K',[0 for i in range(len(crop))])

# %%
crop.insert(6,'pH',[0 for i in range(len(crop))])

# %%
crop.head()
# Out:
#        State_Name Crop_Type       Crop  N  P  K  pH  rainfall  temperature  \
# 0  andhra pradesh    kharif     cotton  0  0  0   0    654.34    29.266667
# 1  andhra pradesh    kharif  horsegram  0  0  0   0    654.34    29.266667
# 2  andhra pradesh    kharif      jowar  0  0  0   0    654.34    29.266667
# 3  andhra pradesh    kharif      maize  0  0  0   0    654.34    29.266667
# 4  andhra pradesh    kharif      moong  0  0  0   0    654.34    29.266667
#
#    Area_in_hectares  Production_in_tons  Yield_ton_per_hec
# 0            7300.0              9400.0           1.287671
# 1            3300.0              1000.0           0.303030
# 2           10100.0             10200.0           1.009901
# 3            2800.0              4900.0           1.750000
# 4            1300.0               500.0           0.384615

# %%
fert.head()
# Out:
#         Crop   N   P   K    pH
# 0  almondnut  70  20  10  5.96
# 1  almondnut  70  20  10  6.12
# 2  almondnut  70  20  10  6.14
# 3  almondnut  70  20  10  6.02
# 4  almondnut  70  20  10  5.84

# %%
for idx,row in crop.iterrows():
    c=row['Crop']
    random_row=fert[fert['Crop']==c].sample()
    temp_values=random_row.values[0]
    crop.loc[idx,['N','P','K','pH']]=temp_values[1:5]

# %%
crop.sample(10)
# Out:
#            State_Name Crop_Type      Crop    N   P   K    pH  rainfall  \
# 898             bihar      rabi      rice   80  40  40  5.64    87.200
# 7588   madhya pradesh      rabi  rapeseed   50  40  20  4.84    73.470
# 22963      tamil nadu    kharif      ragi   50  40  20  5.56   297.660
# 71213           assam    kharif     maize   80  40  20  5.42  1543.760
# 67710          odisha    summer     maize   80  40  20  5.40   113.700
# 78317  andhra pradesh    kharif     moong   20  40  20  5.64   654.340
# 69115       telangana      rabi      ragi   50  40  20  5.62    98.940
# 98434       telangana    kharif    cotton  120  40  20  5.52   770.440
# 9173        rajasthan    kharif     jowar   80  40  40  5.56   510.050
# 73742       karnataka    kharif      ragi   50  40  20  5.64  1246.715
#
#        temperature  Area_in_hectares  Production_in_tons  Yield_ton_per_hec
# 898      23.106000           58064.0            100533.0           1.731417
# ...

# %%
crop.shape
# Out:
# (99849, 12)

# %% [markdown]
# ## Final DataSet Stored in a new csv file

# %%
crop.to_csv('Processed_datasets/FinalDataSet_with_ph.csv',index=True)
